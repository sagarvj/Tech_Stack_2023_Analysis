# %% [markdown]
# <a href="https://colab.research.google.com/github/sagarvj/Tech_Stack-Analysis/blob/main/Tech_Stack(2022).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('survey_results_public.csv')

# %%
df.shape
# Out:
# (47739, 79)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47739 entries, 0 to 47738
# Data columns (total 79 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   ResponseId                      47739 non-null  int64
#  1   MainBranch                      47739 non-null  object
#  2   Employment                      47030 non-null  object
#  3   RemoteWork                      38877 non-null  object
#  4   CodingActivities                38844 non-null  object
#  5   EdLevel                         46947 non-null  object
#  6   LearnCode                       46953 non-null  object
#  7   LearnCodeOnline                 33461 non-null  object
#  8   LearnCodeCoursesCert            19024 non-null  object
#  9   YearsCode                       46798 non-null  object
#  10  YearsCodePro                    34209 non-null  object
#  11  DevType                         40390 non-null  object
#  12  OrgSize                         33751 non-null  object
#  13  PurchaseInfluence               33694 non-null  object
#  14  BuyNewTool                      44507 non-null  object
#  15  Country                         47064 non-null  object
#  16  Currency                        33892 non-null  object
#  17  CompTotal                       25517 non-null  float64
#  18  CompFreq                        29497 non-null  object
#  19  LanguageHaveWorkedWith          46603 non-null  object
#  20  LanguageWantToWorkWith          44062 non-null  object
#  21  DatabaseHaveWorkedWith          39583 non-null  object
#  22  DatabaseWantToWorkWith          33604 non-null  object
#  23  PlatformHaveWorkedWith          32964 non-null  object
#  24  PlatformWantToWorkWith          26592 non-null  object
#  25  WebframeHaveWorkedWith          35278 non-null  object
#  26  WebframeWantToWorkWith          30319 non-null  object
#  27  MiscTechHaveWorkedWith          29813 non-null  object
#  28  MiscTechWantToWorkWith          24292 non-null  object
#  29  ToolsTechHaveWorkedWith         35928 non-null  object
#  30  ToolsTechWantToWorkWith         30786 non-null  object
#  31  NEWCollabToolsHaveWorkedWith    46255 non-null  object
#  32  NEWCollabToolsWantToWorkWith    42209 non-null  object
#  33  OpSysProfessional use           43059 non-null  object
#  34  OpSysPersonal use               46560 non-null  object
#  35  VersionControlSystem            46840 non-null  object
#  36  VCInteraction                   45037 non-null  object
#  37  VCHostingPersonal use           0 non-null      float64
#  38  VCHostingProfessional use       0 non-null      float64
#  39  OfficeStackAsyncHaveWorkedWith  30417 non-null  object
#  40  OfficeStackAsyncWantToWorkWith  20902 non-null  object
#  41  OfficeStackSyncHaveWorkedWith   40824 non-null  object
#  42  OfficeStackSyncWantToWorkWith   31203 non-null  object
#  43  Blockchain                      46640 non-null  object
#  44  NEWSOSites                      46836 non-null  object
#  45  SOVisitFreq                     46644 non-null  object
#  46  SOAccount                       46951 non-null  object
#  47  SOPartFreq                      38647 non-null  object
#  48  SOComm                          46852 non-null  object
#  49  Age                             46555 non-null  object
#  50  Gender                          46481 non-null  object
#  51  Trans                           46141 non-null  object
#  52  Sexuality                       43687 non-null  object
#  53  Ethnicity                       45565 non-null  object
#  54  Accessibility                   44149 non-null  object
#  55  MentalHealth                    43643 non-null  object
#  56  TBranch                         34788 non-null  object
#  57  ICorPM                          23593 non-null  object
#  58  WorkExp                         23900 non-null  float64
#  59  Knowledge_1                     23298 non-null  object
#  60  Knowledge_2                     22732 non-null  object
#  61  Knowledge_3                     22833 non-null  object
#  62  Knowledge_4                     22830 non-null  object
#  63  Knowledge_5                     22775 non-null  object
#  64  Knowledge_6                     22768 non-null  object
#  65  Knowledge_7                     22748 non-null  object
#  66  Frequency_1                     22999 non-null  object
#  67  Frequency_2                     22978 non-null  object
#  68  Frequency_3                     22418 non-null  object
#  69  TimeSearching                   23533 non-null  object
#  70  TimeAnswering                   23438 non-null  object
#  71  Onboarding                      23222 non-null  object
#  72  ProfessionalTech                22687 non-null  object
#  73  TrueFalse_1                     23313 non-null  object
#  74  TrueFalse_2                     23256 non-null  object
#  75  TrueFalse_3                     23276 non-null  object
#  76  SurveyLength                    46239 non-null  object
#  77  SurveyEase                      46283 non-null  object
#  78  ConvertedCompYearly             25343 non-null  float64
# dtypes: float64(5), int64(1), object(73)
# memory usage: 28.8+ MB

# %%
df.head()
# Out:
#    ResponseId                                         MainBranch  \
# 0           1                                      None of these
# 1           2                     I am a developer by profession
# 2           3  I am not primarily a developer, but I write co...
# 3           4                     I am a developer by profession
# 4           5                     I am a developer by profession
#
#             Employment                            RemoteWork  \
# 0                  NaN                                   NaN
# 1  Employed, full-time                          Fully remote
# 2  Employed, full-time  Hybrid (some remote, some in-person)
# 3  Employed, full-time                          Fully remote
# 4  Employed, full-time  Hybrid (some remote, some in-person)
#
#                            CodingActivities  \
# 0                                       NaN
# 1  Hobby;Contribute to open-source projects
# 2                                     Hobby
# 3              I don’t code outside of work
# 4                                     Hobby
#
#                                            EdLevel  \
# 0                                              NaN
# 1                                              NaN
# 2  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 3     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 4     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#                                            LearnCode  \
# 0                                                NaN
# 1                                                NaN
# 2  Books / Physical media;Friend or family member...
# 3  Books / Physical media;School (i.e., Universit...
# 4  Other online resources (e.g., videos, blogs, f...
#
#                                      LearnCodeOnline LearnCodeCoursesCert  \
# 0                                                NaN                  NaN
# 1                                                NaN                  NaN
# 2  Technical documentation;Blogs;Programming Game...                  NaN
# 3                                                NaN                  NaN
# 4  Technical documentation;Blogs;Stack Overflow;O...                  NaN
#
#   YearsCode  ... TimeSearching TimeAnswering Onboarding ProfessionalTech  \
# 0       NaN  ...           NaN           NaN        NaN              NaN
# 1       NaN  ...           NaN           NaN        NaN              NaN
# 2        14  ...           NaN           NaN        NaN              NaN
# 3        20  ...           NaN           NaN        NaN              NaN
# 4         8  ...           NaN           NaN        NaN              NaN
#
#   TrueFalse_1 TrueFalse_2 TrueFalse_3           SurveyLength  \
# 0         NaN         NaN         NaN                    NaN
# 1         NaN         NaN         NaN               Too long
# 2         NaN         NaN         NaN  Appropriate in length
# 3         NaN         NaN         NaN  Appropriate in length
# 4         NaN         NaN         NaN               Too long
#
#                    SurveyEase ConvertedCompYearly
# 0                         NaN                 NaN
# 1                   Difficult                 NaN
# 2  Neither easy nor difficult             40205.0
# 3                        Easy            215232.0
# 4                        Easy                 NaN
#
# [5 rows x 79 columns]

# %%
df.columns
# Out:
# Index(['ResponseId', 'MainBranch', 'Employment', 'RemoteWork',
#        'CodingActivities', 'EdLevel', 'LearnCode', 'LearnCodeOnline',
#        'LearnCodeCoursesCert', 'YearsCode', 'YearsCodePro', 'DevType',
#        'OrgSize', 'PurchaseInfluence', 'BuyNewTool', 'Country', 'Currency',
#        'CompTotal', 'CompFreq', 'LanguageHaveWorkedWith',
#        'LanguageWantToWorkWith', 'DatabaseHaveWorkedWith',
#        'DatabaseWantToWorkWith', 'PlatformHaveWorkedWith',
#        'PlatformWantToWorkWith', 'WebframeHaveWorkedWith',
#        'WebframeWantToWorkWith', 'MiscTechHaveWorkedWith',
#        'MiscTechWantToWorkWith', 'ToolsTechHaveWorkedWith',
#        'ToolsTechWantToWorkWith', 'NEWCollabToolsHaveWorkedWith',
#        'NEWCollabToolsWantToWorkWith', 'OpSysProfessional use',
#        'OpSysPersonal use', 'VersionControlSystem', 'VCInteraction',
#        'VCHostingPersonal use', 'VCHostingProfessional use',
#        'OfficeStackAsyncHaveWorkedWith', 'OfficeStackAsyncWantToWorkWith',
#        'OfficeStackSyncHaveWorkedWith', 'OfficeStackSyncWantToWorkWith',
#        'Blockchain', 'NEWSOSites', 'SOVisitFreq', 'SOAccount', 'SOPartFreq',
#        'SOComm', 'Age', 'Gender', 'Trans', 'Sexuality', 'Ethnicity',
#        'Accessibility', 'MentalHealth', 'TBranch', 'ICorPM', 'WorkExp',
#        'Knowledge_1', 'Knowledge_2', 'Knowledge_3', 'Knowledge_4',
#        'Knowledge_5', 'Knowledge_6', 'Knowledge_7', 'Frequency_1',
#        'Frequency_2', 'Frequency_3', 'TimeSearching', 'TimeAnswering',
#        'Onboarding', 'ProfessionalTech', 'TrueFalse_1', 'TrueFalse_2',
#        'TrueFalse_3', 'SurveyLength', 'SurveyEase', 'ConvertedCompYearly'],
#       dtype='object')

# %%
df = df[['DatabaseHaveWorkedWith','WebframeHaveWorkedWith','LanguageHaveWorkedWith']]

# %%
df.head(2)
# Out:
#   DatabaseHaveWorkedWith WebframeHaveWorkedWith LanguageHaveWorkedWith
# 0                    NaN                    NaN                    NaN
# 1                    NaN                    NaN  JavaScript;TypeScript

# %%
df['LanguageHaveWorkedWith'].value_counts()
# Out:
# HTML/CSS;JavaScript;TypeScript                                      95
# Python                                                              81
# C#                                                                  57
# HTML/CSS;JavaScript;PHP;SQL                                         55
# C#;HTML/CSS;JavaScript;SQL;TypeScript                               50
#                                                                     ..
# Clojure;Perl                                                         1
# Bash/Shell;C;C++;Groovy;HTML/CSS;Java;JavaScript;Python;Rust;SQL     1
# C#;Dart;F#;Lua;PowerShell;SQL                                        1
# Java;PowerShell                                                      1
# Elixir;Python;SQL                                                    1
# Name: LanguageHaveWorkedWith, Length: 4209, dtype: int64

# %%
df['WebframeHaveWorkedWith'].value_counts()
# Out:
# React.js                                                                   212
# Node.js                                                                    161
# Flask                                                                      149
# jQuery                                                                     126
# Node.js;React.js                                                           124
#                                                                           ...
# Angular;FastAPI;React.js                                                     1
# Django;Express;Next.js;Node.js;Phoenix;React.js;Ruby on Rails;Vue.js         1
# Angular;Angular.js;ASP.NET;ASP.NET Core ;Node.js;React.js;Ruby on Rails      1
# Deno;Django;Node.js;React.js                                                 1
# ASP.NET Core ;Django;Laravel;Node.js;Nuxt.js;Symfony;Vue.js                  1
# Name: WebframeHaveWorkedWith, Length: 1611, dtype: int64

# %%
jsbool = df['LanguageHaveWorkedWith'].str.contains('JavaScript')

# %%
jsbool.value_counts(normalize = True)
# Out:
# True     0.655795
# False    0.344205
# Name: LanguageHaveWorkedWith, dtype: float64

# %%
languages = df['LanguageHaveWorkedWith'].str.split(';', expand =True)

# %%
languages.head()
# Out:
#            0           1           2           3       4           5     6   \
# 0         NaN         NaN         NaN         NaN     NaN         NaN   NaN
# 1  JavaScript  TypeScript        None        None    None        None  None
# 2          C#         C++    HTML/CSS  JavaScript  Python        None  None
# 3          C#  JavaScript         SQL  TypeScript    None        None  None
# 4          C#    HTML/CSS  JavaScript         SQL   Swift  TypeScript  None
#
#      7     8     9   ...    32    33    34    35    36    37    38    39  \
# 0   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1  None  None  None  ...  None  None  None  None  None  None  None  None
# 2  None  None  None  ...  None  None  None  None  None  None  None  None
# 3  None  None  None  ...  None  None  None  None  None  None  None  None
# 4  None  None  None  ...  None  None  None  None  None  None  None  None
#
#      40    41
# 0   NaN   NaN
# 1  None  None
# 2  None  None
# 3  None  None
# 4  None  None
#
# [5 rows x 42 columns]

# %%
first_20 = languages.stack().value_counts().head(20)

# %%
first_20.plot(kind = 'bar', figsize =(12,6))
# Out:
# <Axes: >
