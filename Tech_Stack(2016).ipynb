# %% [markdown]
# <a href="https://colab.research.google.com/github/sagarvj/Tech_Stack-Analysis/blob/main/Tech_Stack(2016).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('2016 Stack Overflow Survey Responses.csv')

# %%
df.head(2)
# Out:
#    Unnamed: 0 collector      country   un_subregion     so_region age_range  \
# 0        1888  Facebook  Afghanistan  Southern Asia  Central Asia     20-24
# 1        4637  Facebook  Afghanistan  Southern Asia  Central Asia     30-34
#
#    age_midpoint gender              self_identification  \
# 0          22.0   Male                       Programmer
# 1          32.0   Male  Developer; Engineer; Programmer
#
#                occupation  ...           important_sameend  \
# 0                     NaN  ...                         NaN
# 1  Mobile developer - iOS  ...  This is somewhat important
#
#         important_newtech      important_buildnew  important_buildexisting  \
# 0                     NaN                     NaN                      NaN
# 1  This is very important  This is very important  I don't care about this
#
#           important_promotion    important_companymission  \
# 0                         NaN                         NaN
# ...

# %%
df = df[['tech_do']]

# %%
df.head()
# Out:
#             tech_do
# 0               NaN
# 1  iOS; Objective-C
# 2               NaN
# 3               NaN
# 4               NaN

# %%
df.value_counts()
# Out:
# tech_do
# Java                                                                                                                          169
# C#                                                                                                                            116
# JavaScript; PHP; SQL                                                                                                          111
# JavaScript                                                                                                                    103
# Python                                                                                                                         92
#                                                                                                                              ...
# AngularJS; CoffeeScript; Cloud (AWS, GAE, Azure, etc.); Java; JavaScript; Node.js; Salesforce; SQL                              1
# ...

# %%
language = df['tech_do'].str.split(';',expand = True)

# %%
graph= language.stack().value_counts().head(20)

# %%
graph.plot(kind = 'bar',figsize = (12,6))
# Out:
# <Axes: >
